# %% [markdown]
# ## Testing TVIPS to HDF python converter

# %%
#installation
## need to update pip before installations
import sys
# !{sys.executable} -m pip install tvipsconverter
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: There was an error checking the latest version of pip.

# %%
import tvipsconverter.utils as tv_ut

# %%
tv_ut.
# Out:
# <module 'tvipsconverter.utils' from '/home/massmeye/.local/lib/python3.8/site-packages/tvipsconverter/utils/__init__.py'>
