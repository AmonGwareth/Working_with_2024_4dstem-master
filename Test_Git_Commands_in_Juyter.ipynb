# %%
# !git status
# Out:
# fatal: not a git repository (or any parent up to mount point /home)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# !git -C /home/massmeye/2024_4dstem/ status
# Out:
# On branch OM_DEV
# Your branch is up to date with 'origin/OM_DEV'.
#
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	modified:   Setup_Environment/.ipynb_checkpoints/Installpy4DandHspy-checkpoint.ipynb

# %%
# !git -C /home/massmeye/2024_4dstem/ add .

# %%
# !git -C /home/massmeye/2024_4dstem/ status
# Out:
# On branch OM_DEV
# Your branch is up to date with 'origin/OM_DEV'.
#
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	modified:   Setup_Environment/.ipynb_checkpoints/Installpy4DandHspy-checkpoint.ipynb

# %%
# !git -C /home/massmeye/2024_4dstem/ commit -m 'test commit'
# Out:
# [OM_DEV 7628969] test commit
#  1 file changed, 10 insertions(+), 2 deletions(-)

# %%
# !git -C /home/massmeye/2024_4dstem/ status
# Out:
# On branch OM_DEV
# Your branch is ahead of 'origin/OM_DEV' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean

# %%
# !git -C /home/massmeye/2024_4dstem/ push
# Out:
# Enumerating objects: 7, done.
# Counting objects: 100% (7/7), done.
# Delta compression using up to 64 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 380 bytes | 380.00 KiB/s, done.
# Total 4 (delta 2), reused 0 (delta 0), pack-reused 0
# remote:
# remote: To create a merge request for OM_DEV, visit:
# remote:   https://gitlab.uni-marburg.de/wzmw/strl/tem/2024_4dstem/-/merge_requests/new?merge_request%5Bsource_branch%5D=OM_DEV
# remote:
# To gitlab.uni-marburg.de:wzmw/strl/tem/2024_4dstem.git
#    145e185..7628969  OM_DEV -> OM_DEV

# %%
#kill kernel


#kill and restart kernel
import os
import IPython

# Kill the current process, which will force the kernel to restart
os.kill(os.getpid(), 9)
