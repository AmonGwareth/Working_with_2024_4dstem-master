# %%
## SEM image calibration
print('23:', 1/183)
print('24:', 1/128)
print('26:', 10/938)
print('28', 10/362)
print('29:', 10/682)
print('32:', 1/362)
print('36:', 1/384)
# Out:
# 23: 0.00546448087431694
# 24: 0.0078125
# 26: 0.010660980810234541
# 28 0.027624309392265192
# 29: 0.01466275659824047
# 32: 0.0027624309392265192
# 36: 0.0026041666666666665
