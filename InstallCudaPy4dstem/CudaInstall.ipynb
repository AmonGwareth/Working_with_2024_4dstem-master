# %%
## need to update pip before installations
import sys
# !{sys.executable} -m pip uninstall py4dstem -y
# Out:
# Found existing installation: py4DSTEM 0.14.17
# Uninstalling py4DSTEM-0.14.17:
#   Successfully uninstalled py4DSTEM-0.14.17

# %%
import sys
# !{sys.executable} -m pip uninstall abtem -y
# Out:
# Found existing installation: abtem 1.0.5
# Uninstalling abtem-1.0.5:
#   Successfully uninstalled abtem-1.0.5
