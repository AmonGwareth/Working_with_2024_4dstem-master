# %%
converter.video_type
# Out:
# 'mp4'

# %% [markdown]
# ## Usage Notes
# * filenames have to end with '_000'

# %%
## import the converter
from tvips_converter.converting_data.converting_tvips_to_video import tvips_to_video_converter
# %matplotlib ipympl

# %%
##file 1:

converter = tvips_to_video_converter()
converter.filepath = '//masc_shared/ag_volz/Oliver_Maßmeyer/Perovskites/20240919_PEA2PbI4_Perovskite/Approach1/'
converter.filename = 'PEA2PbI4_approach1__20240919_123950_000' #
converter.n_packages = 1000
converter.quantile = 0.995
converter.vmax = None#600.000
converter.frames_per_second = 25
converter.video_type = 'mp4'

#convert and release the video
converter.convert_to_video()
# Out:
# Found 1 files
# total number of frames = 336
# PEA2PbI4_approach1__20240919_123950_000.tvips
# File 1 of 1. Package 1 of 1
# OpenCV: FFMPEG: tag 0x47504a4d/'MJPG' is not supported with codec id 7 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# finished_loading

# %%
##file 2:

converter = tvips_to_video_converter()
converter.filepath = '//masc_shared/ag_volz/Oliver_Maßmeyer/Perovskites/20240919_PEA2PbI4_Perovskite/Approach1/'
converter.filename = 'PEA2PbI4_approach1__20240919_124016_first_approach_out_of_focus_000'
converter.n_packages = 1000
converter.quantile = 0.995
converter.vmax = None#600.000
converter.frames_per_second = 25
converter.video_type = 'mp4'

#convert and release the video
converter.convert_to_video()
# Out:
# Found 1 files
# OpenCV: FFMPEG: tag 0x47504a4d/'MJPG' is not supported with codec id 7 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# total number of frames = 3271
# PEA2PbI4_approach1__20240919_124016_first_approach_out_of_focus_000.tvips
# File 1 of 1. Package 1 of 4
# File 1 of 1. Package 2 of 4
# File 1 of 1. Package 3 of 4
# File 1 of 1. Package 4 of 4
# finished_loading

# %%
#loop to convert all the data 

## create file list
import os

directory = '//masc_shared/ag_volz/Oliver_Maßmeyer/Perovskites/20240919_PEA2PbI4_Perovskite/Approach1/'
filetype = '.tvips'  # Specify your desired filetype

# List all files in the directory with the specified filetype
filenames = [f for f in os.listdir(directory) if f.endswith(filetype)]

# Remove the file extensions from the filenames
filenames_without_ext = [os.path.splitext(file)[0] for file in filenames]

## make the loop 

for eintrag in filenames_without_ext:

    converter = tvips_to_video_converter()
    converter.filepath = '//masc_shared/ag_volz/Oliver_Maßmeyer/Perovskites/20240919_PEA2PbI4_Perovskite/Approach1/'
    converter.filename = eintrag
    converter.n_packages = 1000
    converter.quantile = 0.995
    converter.vmax = None#600.000
    converter.frames_per_second = 25
    converter.video_type = 'mp4'
    
    #convert and release the video
    converter.convert_to_video()
# Out:
# Found 1 files
# total number of frames = 3271
# PEA2PbI4_approach1__20240919_124016_first_approach_out_of_focus_000.tvips
# File 1 of 1. Package 1 of 4
# OpenCV: FFMPEG: tag 0x47504a4d/'MJPG' is not supported with codec id 7 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# File 1 of 1. Package 2 of 4
# File 1 of 1. Package 3 of 4
# File 1 of 1. Package 4 of 4
# finished_loading
# Found 1 files
# total number of frames = 1621
# PEA2PbI4_approach1__20240919_124812_diff_change_at_one_pos_000.tvips
# File 1 of 1. Package 1 of 2
# OpenCV: FFMPEG: tag 0x47504a4d/'MJPG' is not supported with codec id 7 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# File 1 of 1. Package 2 of 2
# finished_loading
# Found 1 files
# OpenCV: FFMPEG: tag 0x47504a4d/'MJPG' is not supported with codec id 7 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# ...

# %%
##Approach 3
converter = tvips_to_video_converter()
converter.filepath = '//masc_shared/ag_volz/Oliver_Maßmeyer/Perovskites/20240919_PEA2PbI4_Perovskite/APPROACH3/'
converter.filename = 'PEA2PbI4_approach3_20240919_153735_000'
converter.n_packages = 1000
converter.quantile = 0.995
converter.vmax = None#600.000
converter.frames_per_second = 5
converter.video_type = 'mp4'

#convert and release the video
converter.convert_to_video()
# Out:
# Found 1 files
# total number of frames = 752
# PEA2PbI4_approach3_20240919_153735_000.tvips
# File 1 of 1. Package 1 of 1
# OpenCV: FFMPEG: tag 0x47504a4d/'MJPG' is not supported with codec id 7 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# finished_loading

# %%
##Approach 3
converter = tvips_to_video_converter()
converter.filepath = '//masc_shared/ag_volz/Oliver_Maßmeyer/Perovskites/20240919_PEA2PbI4_Perovskite/APPROACH3/'
# converter.filename = 'PEA2PbI4_approach3_20240919_154004_000'
# converter.filename = 'PEA2PbI4_approach3_20240919_161111_000'
# converter.filename = 'PEA2PbI4_approach3_20240919_161500_000'
converter.filename = 'PEA2PbI4_approach3_20240919_161631_000'
converter.n_packages = 50
converter.quantile = 0.995
converter.vmax = None#600.000
converter.frames_per_second = 5
converter.video_type = 'mp4'

#convert and release the video
converter.convert_to_video()
# Out:
# Found 1 files
# OpenCV: FFMPEG: tag 0x47504a4d/'MJPG' is not supported with codec id 7 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# total number of frames = 309
# PEA2PbI4_approach3_20240919_161631_000.tvips
# File 1 of 1. Package 1 of 7
# File 1 of 1. Package 2 of 7
# File 1 of 1. Package 3 of 7
# File 1 of 1. Package 4 of 7
# File 1 of 1. Package 5 of 7
# File 1 of 1. Package 6 of 7
# File 1 of 1. Package 7 of 7
# finished_loading

# %%
##REAL HR

converter = tvips_to_video_converter()
converter.filepath = '//masc_shared/ag_volz/Oliver_Maßmeyer/Perovskites/20240919_PEA2PbI4_Perovskite/PEA2PbI4_4real_HRPARTY/'
converter.filename = 'PEA2PbI4__20240919_162842_000'
converter.n_packages = 1000
converter.quantile = 0.995
converter.vmax = None#600.000
converter.frames_per_second = 5
converter.video_type = 'mp4'

#convert and release the video
converter.convert_to_video()
# Out:
# Found 1 files
# total number of frames = 1024
# OpenCV: FFMPEG: tag 0x47504a4d/'MJPG' is not supported with codec id 7 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# PEA2PbI4__20240919_162842_000.tvips
# File 1 of 1. Package 1 of 2

# %%
##REAL HR

converter = tvips_to_video_converter()
converter.filepath = '//masc_shared/ag_volz/Oliver_Maßmeyer/Perovskites/20240919_PEA2PbI4_Perovskite/PEA2PbI4_4real_HRPARTY/'
converter.filename = 'PEA2PbI4__20240919_163733_000'
converter.n_packages = 1000
converter.quantile = 0.995
converter.vmax = None#600.000
converter.frames_per_second = 5
converter.video_type = 'mp4'

#convert and release the video
converter.convert_to_video()
# Out:
# Found 1 files
# total number of frames = 35
# OpenCV: FFMPEG: tag 0x47504a4d/'MJPG' is not supported with codec id 7 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# PEA2PbI4__20240919_163733_000.tvips
# File 1 of 1. Package 1 of 1
# finished_loading

# %%
#loop to convert all the data 

## create file list
import os

directory = '//masc_shared/ag_volz/Oliver_Maßmeyer/Perovskites/20240919_PEA2PbI4_Perovskite/PEA2PbI4_4real_HRPARTY/'
filetype = '.tvips'  # Specify your desired filetype

# List all files in the directory with the specified filetype
filenames = [f for f in os.listdir(directory) if f.endswith(filetype)]

# Remove the file extensions from the filenames
filenames_without_ext = [os.path.splitext(file)[0] for file in filenames]
print(filenames_without_ext)
## make the loop 

for eintrag in filenames_without_ext:

    converter = tvips_to_video_converter()
    converter.filepath = '//masc_shared/ag_volz/Oliver_Maßmeyer/Perovskites/20240919_PEA2PbI4_Perovskite/PEA2PbI4_4real_HRPARTY/'
    converter.filename = eintrag
    converter.n_packages = 1000
    converter.quantile = 0.995
    converter.vmax = None#600.000
    converter.frames_per_second = 25
    converter.video_type = 'mp4'
    
    #convert and release the video
    converter.convert_to_video()
# Out:
# ['PEA2PbI4__20240919_162842_001', 'PEA2PbI4__20240919_163733_000', 'PEA2PbI4__20240919_162842_000']
# Found 2 files
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[9], line 29
#      26 converter.video_type = 'mp4'
#      28 #convert and release the video
# ---> 29 converter.convert_to_video()
#
# File ~/.conda/envs/4dstem/lib/python3.11/site-packages/tvips_converter/converting_data/converting_tvips_to_video.py:102, in tvips_to_video_converter.convert_to_video(self)
#      96     video_file = cv2.VideoWriter(filepath+filename+'.'+self.video_type,fourcc,self.frames_per_second,size,False)
#      97     #old
#      98     # video_file = cv2.VideoWriter(filepath+'\\'+filename+'.'+self.video_type,fourcc,self.frames_per_second,size,False)
# --> 102     str_prec = str(sx * sy)+ '*' +str_datatype + '=>' +str_datatype
#     105 if True:
# ...

# %%
## update the converter

import sys
# !{sys.executable} -m pip install -i https://test.pypi.org/simple/ tvips-converter==0.0.8.6
# Out:
# Looking in indexes: https://test.pypi.org/simple/
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.0/91.0 kB 2.3 MB/s eta 0:00:00a 0:00:01
# ...
#   Attempting uninstall: tvips-converter
#     Found existing installation: tvips_converter 0.0.8.3
#     Uninstalling tvips_converter-0.0.8.3:
#       Successfully uninstalled tvips_converter-0.0.8.3
# ...
