# %%
pip install pipreqs
pipreqs /path/to/project

# %%
## need to update pip before installations
import sys
# !{sys.executable} -m pip install pipreqs
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Obtaining dependency information for pipreqs from https://files.pythonhosted.org/packages/36/38/cc1343c3a63655e18328e51e00c6e6851be648f1b8babffc5131f1b9f226/pipreqs-0.5.0-py3-none-any.whl.metadata
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Obtaining dependency information for ipython==8.12.3 from https://files.pythonhosted.org/packages/8d/97/8fe103906cd81bc42d3b0175b5534a9f67dccae47d6451131cf8d0d70bb2/ipython-8.12.3-py3-none-any.whl.metadata
#   Using cached ipython-8.12.3-py3-none-any.whl.metadata (5.7 kB)
# ...
#   Obtaining dependency information for nbconvert<8.0.0,>=7.11.0 from https://files.pythonhosted.org/packages/b8/bb/bb5b6a515d1584aa2fd89965b11db6632e4bdc69495a52374bcc36e56cfa/nbconvert-7.16.4-py3-none-any.whl.metadata
# ...

# %%
## need to update pip before installations
import pipreqs

test = pipreqs.pipreqs.generate_requirements_file()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 4
#       1 ## need to update pip before installations
#       2 import pipreqs
# ----> 4 test = pipreqs.pipreqs.generate_requirements_file()
#
# AttributeError: module 'pipreqs' has no attribute 'pipreqs'

# %%
# !pip freeze
# Out:
# abtem==1.0.0b34
# alembic==1.8.1
# anyio==3.6.2
# argon2-cffi==21.3.0
# argon2-cffi-bindings==21.2.0
# arrow==1.2.3
# ase==3.22.1
# asttokens==2.2.0
# async-generator==1.10
# async-lru==2.0.4
# attrs==23.1.0
# Babel==2.11.0
# backcall==0.2.0
# batchspawner @ git+https://github.com/jupyterhub/batchspawner.git@2a9eda060a875a2b65ca9521368fe052a09c3266
# beautifulsoup4==4.11.1
# bleach==5.0.1
# certifi==2022.9.24
# certipy==0.1.3
# cffi==1.15.1
# charset-normalizer==2.1.1
# click==8.1.7
# cloudpickle==3.0.0
# comm==0.2.2
# contourpy==1.0.6
# cryptography==38.0.4
# cycler==0.11.0
# dask==2023.5.0
# debugpy==1.6.4
# decorator==5.1.1
# defusedxml==0.7.1
# docopt==0.6.2
# entrypoints==0.4
# executing==1.2.0
# fastjsonschema==2.16.2
# fonttools==4.38.0
# fqdn==1.5.1
# fsspec==2024.5.0
# greenlet==2.0.1
# h11==0.14.0
# h5py==3.10.0
# httpcore==1.0.5
# httpx==0.27.0
# hyperspy==2.0.1
# hyperspy_gui_ipywidgets==2.0.1
# hyperspy_gui_traitsui==2.0.1
# idna==3.4
# imageio==2.33.1
# ...

# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- -----------
# abtem                     1.0.0b34
# alembic                   1.8.1
# anyio                     3.6.2
# argon2-cffi               21.3.0
# argon2-cffi-bindings      21.2.0
# arrow                     1.2.3
# ase                       3.22.1
# asttokens                 2.2.0
# async-generator           1.10
# async-lru                 2.0.4
# attrs                     23.1.0
# Babel                     2.11.0
# backcall                  0.2.0
# batchspawner              1.2.0
# beautifulsoup4            4.11.1
# bleach                    5.0.1
# certifi                   2022.9.24
# certipy                   0.1.3
# cffi                      1.15.1
# charset-normalizer        2.1.1
# click                     8.1.7
# cloudpickle               3.0.0
# comm                      0.2.2
# contourpy                 1.0.6
# cryptography              38.0.4
# cycler                    0.11.0
# ...

# %%
# !pip3 freeze > requirements.txt  # Python3
