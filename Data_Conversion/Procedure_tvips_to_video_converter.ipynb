# %%
from tvips_converter.converting_data.converting_tvips_to_video import tvips_to_video_converter
# %matplotlib ipympl
converter = tvips_to_video_converter()
converter.filepath = r'/masc_shared/ag_volz/marc3/test_data/3010_tvips_scan/'
converter.filename = 'scan_1_40x30_0deg_20cm_30nm_40ms_250_000'
converter.n_packages = 1000
converter.quantile = 0.995
converter.vmax = None#600.000
converter.frames_per_second = 25

converter.convert_to_video()
# Out:
# Found 1 files
# total number of frames = 1331
# scan_1_40x30_0deg_20cm_30nm_40ms_250_000.tvips
# File 1 of 1. Package 1 of 2
# OpenCV: FFMPEG: tag 0x47504a4d/'MJPG' is not supported with codec id 7 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# File 1 of 1. Package 2 of 2
# finished_loading

# %%
import sys
# !{sys.executable} -m pip install -i https://test.pypi.org/simple/ tvips-converter==0.0.8.6
# Out:
# Looking in indexes: https://test.pypi.org/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.0/91.0 kB 4.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tvips-converter
#     Found existing installation: tvips_converter 0.0.8.5
#     Uninstalling tvips_converter-0.0.8.5:
#       Successfully uninstalled tvips_converter-0.0.8.5
# ...
