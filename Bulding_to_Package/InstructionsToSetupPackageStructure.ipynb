# %% [markdown]
# ## What to install
# * taken from : https://packaging.python.org/en/latest/tutorials/packaging-projects/

# %%
## need to update pip before installations
import sys
# !{sys.executable} -m pip install --upgrade build
# Out:
# ...
#
# [notice] A new release of pip is available: 24.1.2 -> 25.0.1
# [notice] To update, run: /home/massmeye/.conda/envs/py4DSTEMnewVersion/bin/python -m pip install --upgrade pip

# %%
## install hatch
# !{sys.executable} -m pip install hatch
# Out:
# ...
#   Using cached hatchling-1.27.0-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# ...
#   Using cached pathspec-0.12.1-py3-none-any.whl.metadata (21 kB)
# ...
#   Using cached pluggy-1.5.0-py3-none-any.whl.metadata (4.8 kB)
# ...
#   Using cached trove_classifiers-2025.2.18.16-py3-none-any.whl.metadata (2.3 kB)
# ...
#   Using cached h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# ...
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.8/125.8 kB 29.6 MB/s eta 0:00:00
# Using cached hatchling-1.27.0-py3-none-any.whl (75 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 kB 21.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 25.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 25.2 MB/s eta 0:00:00
# Using cached packaging-24.2-py3-none-any.whl (65 kB)
# ...

# %%
## build the package -- > change version in pyproject.toml
import sys
# !{sys.executable} -m build
# Out:
# * Creating isolated environment: venv+pip...
# * Installing packages in isolated environment:
#   - hatchling
# * Getting build dependencies for sdist...
# * Building sdist...
# * Building wheel from sdist
# * Creating isolated environment: venv+pip...
# * Installing packages in isolated environment:
#   - hatchling
# * Getting build dependencies for wheel...
# * Building wheel...
# Successfully built functionpackageom-0.0.7.tar.gz and functionpackageom-0.0.7-py3-none-any.whl

# %%
## need to update pip before installations
import sys
# !{sys.executable} -m pip install --upgrade twine
# Out:
# ...
#
# [notice] A new release of pip is available: 24.1.2 -> 25.0.1
# [notice] To update, run: /home/massmeye/.conda/envs/py4DSTEMnewVersion/bin/python -m pip install --upgrade pip

# %%
## upload 

# !{sys.executable} -m twine upload --repository testpypi dist/* --verbose -p pypi-AgENdGVzdC5weXBpLm9yZwIkOGI4ZjI0ZTQtZDg2MC00ZWJjLThkMjAtZGJmNWMzOGU3OWVkAAIqWzMsIjgwNTdkNjFjLTY5MjctNDkwNS05OWQ3LTc0YzEzYWY3Yzg3NyJdAAAGIBm3vWerwf-FhkEDL4yxv_HkmArO3iLn2hk7O93kU-px
# Out:
# Uploading distributions to https://test.pypi.org/legacy/
# INFO     dist/functionpackageom-0.0.2-py3-none-any.whl (22.5 KB)
# INFO     dist/functionpackageom-0.0.5-py3-none-any.whl (23.5 KB)
# INFO     dist/functionpackageom-0.0.6-py3-none-any.whl (23.5 KB)
# INFO     dist/functionpackageom-0.0.7-py3-none-any.whl (23.6 KB)
# INFO     dist/functionpackageom-0.0.2.tar.gz (24.5 KB)
# INFO     dist/functionpackageom-0.0.5.tar.gz (25.6 KB)
# INFO     dist/functionpackageom-0.0.6.tar.gz (719.4 KB)
# INFO     dist/functionpackageom-0.0.7.tar.gz (718.1 KB)
# INFO     username set by command options
# INFO     password set by command options
# INFO     username: __token__
# INFO     password: <hidden>
# Uploading functionpackageom-0.0.2-py3-none-any.whl
# 100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.8/25.8 kB • 00:00 • 118.0 MB/s
# INFO     Response from https://test.pypi.org/legacy/:
#          200 OK
# INFO     <html>
#           <head>
#            <title>200 OK</title>
# ...

# %%
## install final package
import sys
# !{sys.executable} -m pip install -i https://test.pypi.org/simple/ FunctionPackageOM==0.0.7
# Out:
# Looking in indexes: https://test.pypi.org/simple/
# ...
#   Attempting uninstall: FunctionPackageOM
#     Found existing installation: FunctionPackageOM 0.0.5
#     Uninstalling FunctionPackageOM-0.0.5:
#       Successfully uninstalled FunctionPackageOM-0.0.5
# ...

# %%
from FunctionPackageOM import Ollis_Functions
