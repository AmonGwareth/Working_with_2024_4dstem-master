# %%
# Import all needed packages
import os
import numpy as np
import matplotlib.pyplot as plt
import hyperspy.api as hs
import py4DSTEM
import ase.io
import abtem
import matplotlib
import scipy
import h5py

from FunctionPackageOM import User_Functions
from FunctionPackageOM.cepstral import browser
from FunctionPackageOM.Plot_Style import Plot_Style_OM_activate

# Load custom plot style
Plot_Style_OM_activate(white_bkg_for_visualization=True)

# interactivity for plots
# %matplotlib ipympl
# %matplotlib widget
# %matplotlib inline

# Print the py4DSTEM version
print(py4DSTEM.__version__)
# Out:
# cupyx.jit.rawkernel is experimental. The interface can change in the future.
# 0.14.18

# %%
## make overview of folder
fpSingle = '//masc_shared/ag_volz/Oliver_Maßmeyer/Turchanin_MoSe2_WSe2/2025_04_22_OM043/Single'
Single_files = User_Functions.ListFilesFormatedSortedByTimeAndFilterForString(fpSingle, 'prz')
# Out:
# Single/
#     0: Single_OM043.prz
#     1: Single_OM043_0001.prz
#     2: Single_OM043_0002.prz
#     3: Single_OM043_0003_ZLP_ref.prz
#     4: Single_OM043_0004.prz
#     5: Single_OM043_000520eVshift_300umeV_dispersion.prz

# %%
## load 2D spectral data for energy calibration
Energy_shift_eV = 20
Ref_Spekt1 = hs.load(filenames=os.path.join(fpSingle,Single_files[3]), signal_type = 'EELS')
Ref_Spekt2 = hs.load(filenames=os.path.join(fpSingle,Single_files[4]), signal_type = 'EELS')
Ref_Spekt3 = hs.load(filenames=os.path.join(fpSingle,Single_files[1]), signal_type = 'EELS')

# %%
## add both images for calibration
Calibration_Spekt = Ref_Spekt1+Ref_Spekt2
## plot with interactive spectrum extraction
Calibration_Spekt.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import sys
# !{sys.executable} -m jupyter --version
# Out:
# Selected Jupyter core packages...
# IPython          : 9.1.0
# ipykernel        : 6.29.5
# ipywidgets       : 8.1.6
# jupyter_client   : 8.6.3
# jupyter_core     : 5.7.2
# jupyter_server   : 2.15.0
# jupyterlab       : 4.4.1
# nbclient         : 0.10.2
# nbconvert        : 7.16.6
# nbformat         : 5.10.4
# notebook         : 7.4.1
# qtconsole        : 5.6.1
# traitlets        : 5.14.3

# %%
import sys
# !{sys.executable} -m pip install --upgrade ipympl

# %%
## fixing?????
# !{sys.executable} -m pip install IPython
# !{sys.executable} -m pip install ipykernel
# !{sys.executable} -m pip install ipywidgets
# !{sys.executable} -m pip install jupyter_client
# !{sys.executable} -m pip install jupyter_core
# !{sys.executable} -m pip install jupyter_server
# !{sys.executable} -m pip install nbclient
# !{sys.executable} -m pip install nbconvert
# !{sys.executable} -m pip install nbformat
# !{sys.executable} -m pip install notebook
# !{sys.executable} -m pip install qtconsole
# !{sys.executable} -m pip install traitlets
# !{sys.executable} -m pip install ipympl

# %%
## might be relant here as well
# !pip install IPython
# !pip install ipykernel
# !pip install ipywidgets
# !pip install jupyter_client
# !pip install jupyter_core
# !pip install jupyter_server
# !pip install nbclient
# !pip install nbconvert
# !pip install nbformat
# !pip install notebook
# !pip install qtconsole
# !pip install traitlets
# !pip install ipympl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# %%bash
# pip install --upgrade jupyter_client
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# !{sys.executable} -m pip install jupyter_client
# Out:
# /bin/bash: {sys.executable}: command not found

# %%
# !pip install --upgrade jupyter_client
# !{sys.executable} -m pip install --upgrade jupyter_client
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# /bin/bash: {sys.executable}: command not found

# %%
# %%bash
# pip list
# Out:
# Package                           Version
# --------------------------------- --------------
# abtem                             1.0.6
# alembic                           1.8.1
# anyio                             4.9.0
# argon2-cffi                       23.1.0
# argon2-cffi-bindings              21.2.0
# arrow                             1.3.0
# asciitree                         0.3.3
# ase                               3.24.0
# asteval                           1.0.6
# asttokens                         3.0.0
# async-generator                   1.10
# async-lru                         2.0.5
# attrs                             25.3.0
# babel                             2.17.0
# backcall                          0.2.0
# backports.tarfile                 1.2.0
# batchspawner                      1.2.0
# beautifulsoup4                    4.13.3
# bleach                            6.2.0
# blinker                           1.9.0
# bokeh                             3.7.2
# ...
